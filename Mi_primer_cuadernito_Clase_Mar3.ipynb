# %% [markdown]
# `interactive python notebook .ipynb`

# %% [markdown]
# # La nostalgía del melómano
# Este es mi libro favorito
# [Libreria Nacional](https://librerianacional.com/producto/la-nostalgia-del-melomano)
#
# [como aprender markdown](https://www.markdownguide.org/basic-syntax/)
#
# ![La nostalgia](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRiXEpqq_vgsZgOASQAi9L5OvOL4vJY5sg9Xw&usqp=CAU)
#
# ![836aacf03b68a5aea0573a58b9ab90bc.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # La nostalgía del melómano

# %% [markdown]
# Este es mi libro favorito
# [Libreria Nacional](https://librerianacional.com/producto/la-nostalgia-del-melomano)
#
# [como aprender markdown](https://www.markdownguide.org/basic-syntax/)
#
# ![La nostalgia](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRiXEpqq_vgsZgOASQAi9L5OvOL4vJY5sg9Xw&usqp=CAU)
#
# *Hola esta es letra cursiva*
#
# **Hacer el texto en negrilla**
#
# ***Combino el texto con negrita y cursiva***
#
# > esto pone una sangria, sirve para enfatizar

# %% [markdown]
# # Lenguaje LaTeX

# %% [markdown]
# El lenguaje latex se usa para colocar ecuaciones matemáticas, de forma profesional.
#
# Es el lenguaje estándar por la mayoria de los científicos en el mundo.
#
# $$y=x^2$$
#
# $$\frac{dx}{dt}=kC$$

# %% [markdown]
# #Mi primera linea de codigo

# %%
print("Hola Amigui")
# Out:
# Hola Amigui
